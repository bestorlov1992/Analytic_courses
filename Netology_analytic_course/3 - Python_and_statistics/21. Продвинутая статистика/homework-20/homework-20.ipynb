# %% [markdown]
# <a href="https://colab.research.google.com/github/yustinaivanova/netology_statistics/blob/master/dz_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашняя работа №4

# %% [markdown]
# # Виды распределений

# %% [markdown]
# Загрузить таблицу и построить график распределений. Найти нормальное распределение.

# %%
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Таблица цен на дома в Бостоне

# %% [markdown]
# Основные значения:
#
# * CRIM: This is the per capita crime rate by town
# * ZN: This is the proportion of residential land zoned for lots larger than 25,000 sq.ft.
# * INDUS: This is the proportion of non-retail business acres per town.
# * CHAS: This is the Charles River dummy variable (this is equal to 1 if tract bounds river; 0 otherwise)
# * NOX: This is the nitric oxides concentration (parts per 10 million)
# * RM: This is the average number of rooms per dwelling
# * AGE: This is the proportion of owner-occupied units built prior to 1940
# * DIS: This is the weighted distances to five Boston employment centers
# * RAD: This is the index of accessibility to radial highways
# * TAX: This is the full-value property-tax rate per 10,000 dollars
# * PTRATIO: This is the pupil-teacher ratio by town
# * B: This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# * LSTAT: This is the percentage lower status of the population
# * MEDV: This is the median value of owner-occupied homes in 1000 dollars

# %%
import ssl
# следующая строчка подключает сертификат для защищенного соединения
ssl._create_default_https_context = ssl._create_unverified_context
url='http://yustiks.ru/dataset/housing.csv'
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data=pd.read_csv(url,  delim_whitespace=True, names=names)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# Нарисовать частотные графики для всех значений. Можете ли вы найти следующие распределения в данных графиках?
#
#
# 1.   Нормальное
# 2.   Равномерное
# 3.   Биноминальное
# 4.   Бернулли
# 5.   Геометрическое
# 6.   Логнормальное

# %%
plt.scatter(data['LSTAT'], data['MEDV'])

# %%
for el in data.columns:
    fig, ax = plt.subplots()
    plt.hist(data[el], bins=30, ec='white')
    plt.title(el)

# %%
data.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# c:\python\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   """Entry point for launching an IPython kernel.
# <style type="text/css">
# #T_780e9_row0_col0, #T_780e9_row1_col1, #T_780e9_row2_col2, #T_780e9_row3_col3, #T_780e9_row4_col4, #T_780e9_row5_col5, #T_780e9_row6_col6, #T_780e9_row7_col7, #T_780e9_row8_col8, #T_780e9_row9_col9, #T_780e9_row10_col10, #T_780e9_row11_col11, #T_780e9_row12_col12, #T_780e9_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_780e9_row0_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_780e9_row0_col2 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_780e9_row0_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_780e9_row0_col4 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_780e9_row0_col5 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_780e9_row0_col6, #T_780e9_row1_col13 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_780e9_row0_col7, #T_780e9_row11_col4, #T_780e9_row11_col10 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_780e9_row0_col8 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_780e9_row0_col9, #T_780e9_row2_col8, #T_780e9_row8_col0 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_780e9_row0_col10 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_780e9_row0_col11, #T_780e9_row13_col9 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_780e9_row0_col12 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_780e9_row0_col13, #T_780e9_row9_col5 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_780e9_row1_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_780e9_row1_col2, #T_780e9_row1_col6, #T_780e9_row8_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_780e9_row1_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_780e9_row1_col4, #T_780e9_row1_col9 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_780e9_row1_col5, #T_780e9_row2_col0 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_780e9_row1_col7, #T_780e9_row9_col4, #T_780e9_row13_col5 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_780e9_row1_col8, #T_780e9_row5_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_780e9_row1_col10, #T_780e9_row9_col3, #T_780e9_row13_col8 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_780e9_row1_col11 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_780e9_row1_col12, #T_780e9_row5_col2, #T_780e9_row6_col3, #T_780e9_row10_col11 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_780e9_row2_col1, #T_780e9_row7_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_780e9_row2_col3, #T_780e9_row8_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_780e9_row2_col4 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_780e9_row2_col5, #T_780e9_row7_col12 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_780e9_row2_col6 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_780e9_row2_col7, #T_780e9_row4_col1, #T_780e9_row11_col8 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_780e9_row2_col9 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_780e9_row2_col10, #T_780e9_row13_col1 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_780e9_row2_col11, #T_780e9_row11_col9, #T_780e9_row12_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_780e9_row2_col12, #T_780e9_row6_col12, #T_780e9_row12_col6 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_780e9_row2_col13 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_780e9_row3_col0 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_780e9_row3_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_780e9_row3_col2 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_780e9_row3_col4 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_780e9_row3_col5 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_780e9_row3_col6 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_780e9_row3_col7 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_780e9_row3_col8, #T_780e9_row3_col9 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_780e9_row3_col10 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_780e9_row3_col11 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_780e9_row3_col12 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_780e9_row3_col13 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_780e9_row4_col0, #T_780e9_row12_col10 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_780e9_row4_col2 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_780e9_row4_col3, #T_780e9_row5_col3, #T_780e9_row5_col8 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_780e9_row4_col5, #T_780e9_row13_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_780e9_row4_col6 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_780e9_row4_col7, #T_780e9_row6_col1, #T_780e9_row7_col2, #T_780e9_row7_col4, #T_780e9_row7_col6, #T_780e9_row7_col8, #T_780e9_row7_col9, #T_780e9_row8_col11, #T_780e9_row9_col11, #T_780e9_row10_col3, #T_780e9_row11_col0, #T_780e9_row12_col5, #T_780e9_row12_col13, #T_780e9_row13_col0, #T_780e9_row13_col10, #T_780e9_row13_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_780e9_row4_col8 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_780e9_row4_col9 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_780e9_row4_col10 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_780e9_row4_col11 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_780e9_row4_col12, #T_780e9_row8_col2 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_780e9_row4_col13 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_780e9_row5_col1 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_780e9_row5_col4, #T_780e9_row13_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_780e9_row5_col6 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_780e9_row5_col7 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_780e9_row5_col9, #T_780e9_row10_col5 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_780e9_row5_col10, #T_780e9_row12_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_780e9_row5_col11 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_780e9_row5_col12 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_780e9_row5_col13 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_780e9_row6_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_780e9_row6_col2 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_780e9_row6_col4 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_780e9_row6_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_780e9_row6_col7 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_780e9_row6_col8 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_780e9_row6_col9 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_780e9_row6_col10, #T_780e9_row7_col11 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_780e9_row6_col11 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_780e9_row6_col13 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_780e9_row7_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_780e9_row7_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_780e9_row7_col5 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_780e9_row7_col10 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_780e9_row7_col13 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_780e9_row8_col4 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_780e9_row8_col5 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_780e9_row8_col6 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_780e9_row8_col7, #T_780e9_row9_col13, #T_780e9_row12_col7 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_780e9_row8_col9 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_780e9_row8_col10 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_780e9_row8_col12 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_780e9_row8_col13, #T_780e9_row11_col2 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_780e9_row9_col0, #T_780e9_row12_col9 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_780e9_row9_col1 {
#   background-colo

# %% [markdown]
# Построить матрицу корреляций для данной таблицы и выбрать максимально коррелирующий атрибут (несколько атрибутов) с ценой на дома (MEDV атрибут).

# %% [markdown]
# Написать **линейную регрессию** на два атрибута. Допустим, мы хотим предсказать цену дома (MEDV) в Бостоне, зная что цена на дом имеет линейную зависимость с атрибутом LSTAT.

# %% [markdown]
# 1.   Разделить данные на 80% тренировочных, 20% тестовых
# 2.   Составить модель линейной регрессии
# 3.   Посчитать ошибку модели на тестовых данных
# 4.   Сделать точечный график данных и полученной прямой линейной регрессии

# %%
from sklearn.model_selection import train_test_split
medv = data.MEDV.to_numpy().reshape(-1,1)
lstat = data.LSTAT.to_numpy().reshape(-1,1)
x_tr, x_te, y_tr, y_te = train_test_split(
    lstat
    , medv
    , test_size= 0.2
)

# %%
x_tr

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(x_tr, y_tr)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
print(mean_squared_error(y_te, model.predict(x_te)))
print(mean_absolute_error(y_te, model.predict(x_te)))
# Out:
# 39.97663276110484
# 4.567791324234392

# %%
plt.scatter(lstat, medv)
plt.plot(lstat, model.predict(lstat), c='red')

# %% [markdown]
# Загрузить таблицу Happiness report. Посчитать матрицу ковариаций попарно.

# %%
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
data=pd.read_csv(url)
data.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# 1                      23.0
# 2                      12.0
# 3                      13.0
# 4                      18.0

# %%
data.dropna(inplace=True)

# %%
data.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# c:\python\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   """Entry point for launching an IPython kernel.
# <style type="text/css">
# #T_188c9_row0_col0, #T_188c9_row1_col1, #T_188c9_row2_col2, #T_188c9_row3_col3, #T_188c9_row4_col4, #T_188c9_row5_col5, #T_188c9_row6_col6, #T_188c9_row7_col7, #T_188c9_row8_col8, #T_188c9_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_188c9_row0_col1 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_188c9_row0_col2 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_188c9_row0_col3 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_188c9_row0_col4 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_188c9_row0_col5 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_188c9_row0_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_188c9_row0_col7 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_188c9_row0_col8 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_188c9_row0_col9 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_188c9_row1_col0 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_188c9_row1_col2, #T_188c9_row1_col5, #T_188c9_row2_col1, #T_188c9_row4_col6, #T_188c9_row6_col0, #T_188c9_row6_col3, #T_188c9_row6_col4, #T_188c9_row6_col7, #T_188c9_row6_col8, #T_188c9_row6_col9, #T_188c9_row9_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_188c9_row1_col3, #T_188c9_row4_col1 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_188c9_row1_col4 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_188c9_row1_col6 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_188c9_row1_col7 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_188c9_row1_col8 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_188c9_row1_col9 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_188c9_row2_col0 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_188c9_row2_col3, #T_188c9_row3_col5, #T_188c9_row7_col3 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_188c9_row2_col4 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_188c9_row2_col5, #T_188c9_row3_col1 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_188c9_row2_col6 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_188c9_row2_col7 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_188c9_row2_col8, #T_188c9_row7_col6 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_188c9_row2_col9 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_188c9_row3_col0, #T_188c9_row9_col3 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_188c9_row3_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_188c9_row3_col4 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_188c9_row3_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_188c9_row3_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_188c9_row3_col8 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_188c9_row3_col9 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_188c9_row4_col0 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_188c9_row4_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_188c9_row4_col3 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_188c9_row4_col5, #T_188c9_row5_col6, #T_188c9_row5_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_188c9_row4_col7, #T_188c9_row9_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_188c9_row4_col8 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_188c9_row4_col9, #T_188c9_row9_col4 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_188c9_row5_col0 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_188c9_row5_col1, #T_188c9_row6_col1 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_188c9_row5_col2 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_188c9_row5_col3 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_188c9_row5_col4 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_188c9_row5_col8, #T_188c9_row8_col2 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_188c9_row5_col9 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_188c9_row6_col2 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_188c9_row6_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_188c9_row7_col0, #T_188c9_row7_col8 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_188c9_row7_col1 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_188c9_row7_col2, #T_188c9_row7_col9 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_188c9_row7_col4 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_188c9_row7_col5 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_188c9_row8_col0, #T_188c9_row8_col4 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_188c9_row8_col1 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_188c9_row8_col3 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_188c9_row8_col5 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_188c9_row8_col6 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_188c9_row8_col7 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_188c9_row8_col9 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_188c9_row9_col0 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_188c9_row9_col1 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_188c9_row9_col2 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_188c9_row9_col7 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_188c9_row9_col8 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_188c9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Ladder</th>
#       <th class="col_heading level0 col1" >SD of Ladder</th>
#       <th class="col_heading level0 col2" >Positive affect</th>
#       <th class="col_heading level0 col3" >Negative affect</th>
#       <th class="col_heading level0 col4" >Social support</th>
#       <th class="col_heading level0 col5" >Freedom</th>
#       <th class="col_heading level0 col6" >Corruption</th>
#       <th class="col_heading level0 col7" >Generosity</th>
#       <th class="col_heading level0 col8" >Log of GDP
# per capita</th>
#       <th class="col_heading level0 col9" >Healthy life
# expectancy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_188c9_level0_row0" class="row_heading level0 row0" >Ladder</th>
#       <td id="T_188c9_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_188c9_row0_col1" class="data row0 col1" >0.56</td>
#       <td id="T_188c9_row0_col2" class="data row0 col2" >0.51</td>
#       <td id="T_188c9_row0_col3" class="data row0 col3" >0.54</td>
#       <td id="T_188c9_row0_col4" class="data row0 col4" >0.83</td>
#       <td id="T_188c9_row0_col5" class="data row0 col5" >0.55</td>
#       <td id="T_188c9_row0_col6" class="data row0 col6" >0.22</td>
#       <td id="T_188c9_row0_col7" class="data row0 col7" >0.49</td>
#       <td id="T_188c9_row0_col8" class="data row0 col8" >0.82</td>
#       <td id="T_188c9_row0_col9" class="data row0 col9" >0.83</td>
#     </tr>
#     <tr>
#       <th id="T_188c9_level0_row1" class="row_heading level0 row1" >SD of Ladder</th>
#       <td id="T_188c9_row1_col0" class="data row1 col0" >0.56</td>
#       <td id="T_188c9_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_188c9_row1_col2" class="data row1 col2" >0.09</td>
#       <td id="T_188c9_row1_col3" class="data row1 col3" >0.63</td>
#       <td id="T_188c9_row1_col4" class="data row1 col4" >0.60</td>
#       <td id="T_188c9_row1_col5" class="data row1 col5" >0.25</td>
#       <td id="T_188c9_row1_col6" class="data row1 col6" >0.25</td>
#       <td id="T_188c9_row1_col7" class="data row1 col7" >0.39</td>
#       <td id="T_188c9_row1_col8" class="data row1 col8" >0.66</td>
#       <td id="T_188c9_row1_col9" class="data row1 col9" >0.64</td>
#     </tr>
#     <tr>
#       <th id="T_188c9_level0_row2" class="row_heading level0 row2" >Positive affect</th>
#       <td id="T_188c9_row2_col0" class="data row2 col0" >0.51</td>
#       <td id="T_188c9_row2_col1" class="data row2 col1" >0.09</td>
#       <td id="T_188c9_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_188c9_row2_col3" class="data row2 col3" >0.35</td>
#       <td id="T_18

# %% [markdown]
# Сколько в данной таблице отсутствующих значений? Написать ответ. Если есть отсутствующие значения в выборке country, убрать (drop).

# %% [markdown]
# Сколько стран в выборке? Написать ответ.

# %% [markdown]
# Построить матрицу корреляций для таблицы. Какие можно сделать выводы?

# %% [markdown]
# # Дискретное распределение случайной величины

# %% [markdown]
# Напишите код для моделирования 10 подбрасываний игрального кубика. Начертите диаграму histogram. Какое это распределение?

# %%
ar = np.array([], dtype='int32')


for _ in range(1000):
    sum_ = 0
    for _ in range(100):
        sum_ += np.random.randint(1, 7)
    ar = np.append(ar, sum_)
plt.hist(ar)
# Out:
# (array([  9.,  56., 125., 224., 251., 196., 101.,  31.,   6.,   1.]),
#  array([302. , 313.1, 324.2, 335.3, 346.4, 357.5, 368.6, 379.7, 390.8,
#         401.9, 413. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Смоделируйте 1000 раз сумму по 100 подбрасываний. Начертите диаграму histogram. Почему график изменился? Почему можно применить центральную предельную теорему?
