# %% [markdown]
# Возьмите свою архитектуру двх.Предложите несколько (5-6)
# проверок, которые мы можем проводить при записи новых
# данных, чтобы убеждаться, что все хорошо

# %%
# !pip install PyMuPDF
# Out:
# ...
#    ---------------------------------------- 11.7/11.7 MB 825.4 kB/s eta 0:00:00
# ...

# %%
import fitz

pdffile = "3 hw.pdf"
doc = fitz.open(pdffile)
page = doc.load_page(0)  # number of page
pix = page.get_pixmap()
output = "3 hw.png"
pix.save(output)
doc.close()

# %%
from PIL import Image
img = Image.open("3 hw.png")
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=612x792>

# %% [markdown]
# - Время покупки и другие даты больше определенного года, например больше 2000-01-01 00:00:00
# - Цена покупки больше 0
# - количество мест в самолете больше 0
# - название самолета содержит хотя бы один символ
# - дальность и скорость полета больше 0
# - имя фамили отчество содержат хотя бы 1 символ
# - Адрес компании содержит хотя бы город, улицу и номер дома
# - Время прилета больше времени вылета в билете
# - Время покупки билета меньше времени вылета
