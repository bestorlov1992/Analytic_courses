# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Владельцам сайта для продажи билетов в кино нужна помощь.
# В датасете предложен некоторый набор метрик, но он не полный.
# Определите метрики, которые больше всего влияют на доход.
# Для этого постройте пирамиду метрик и проведите корреляционный анализ.

# %%
df = pd.read_excel('hw.xlsx')                
df.head()
# Out:
#         Дата  Пользователи  Новые пользователи  Доля новых пользователей  \
# 0 2017-12-31         23095                1603                  0.069409
# 1 2017-12-30         29918                2116                  0.070727
# 2 2017-12-29         38953                3029                  0.077760
# 3 2017-12-28         41326                3228                  0.078111
# 4 2017-12-27         34148                2199                  0.064396
#
#    Количество платящих пользователей  Количество платящих пользователей.1  \
# 0                               1828                             0.009687
# 1                               2727                             0.014452
# 2                               4219                             0.022358
# 3                               4710                             0.024960
# 4                               3018                             0.015994
#
#    Количество покупок  Количество покупок.1  \
# ...

# %%
df.dtypes
# Out:
# Дата                                              datetime64[ns]
# Пользователи                                               int64
# Новые пользователи                                         int64
# Доля новых пользователей                                 float64
# Количество платящих пользователей                          int64
# Количество платящих пользователей.1                      float64
# Количество покупок                                         int64
# Количество покупок.1                                     float64
# Количество покупок на платящего пользователя             float64
# Выручка, RUB                                             float64
# Средняя выручка на пользователя, RUB                     float64
# Средняя выручка на платящего пользователя, RUB           float64
# Вернувшиеся                                                int64
# Выручка, RUB.1                                           float64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 17 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Дата                                            125 non-null    datetime64[ns]
#  1   Пользователи                                    125 non-null    int64
#  2   Новые пользователи                              125 non-null    int64
#  3   Доля новых пользователей                        125 non-null    float64
#  4   Количество платящих пользователей               125 non-null    int64
#  5   Количество платящих пользователей.1             125 non-null    float64
#  6   Количество покупок                              125 non-null    int64
#  7   Количество покупок.1                            125 non-null    float64
#  8   Количество покупок на платящего пользователя    125 non-null    float64
# ...

# %%
df.head()
# Out:
#         Дата  Пользователи  Новые пользователи  Доля новых пользователей  \
# 0 2017-12-31         23095                1603                  0.069409
# 1 2017-12-30         29918                2116                  0.070727
# 2 2017-12-29         38953                3029                  0.077760
# 3 2017-12-28         41326                3228                  0.078111
# 4 2017-12-27         34148                2199                  0.064396
#
#    Количество платящих пользователей  Количество платящих пользователей.1  \
# 0                               1828                             0.009687
# 1                               2727                             0.014452
# 2                               4219                             0.022358
# 3                               4710                             0.024960
# 4                               3018                             0.015994
#
#    Количество покупок  Количество покупок.1  \
# ...

# %%
df.corr().loc[['Выручка, RUB.1']]
# Out:
#                 Пользователи  Новые пользователи  Доля новых пользователей  \
# Выручка, RUB.1      0.838978            0.843391                  0.237746
#
#                 Количество платящих пользователей  \
# Выручка, RUB.1                           0.935762
#
#                 Количество платящих пользователей.1  Количество покупок  \
# Выручка, RUB.1                             0.935762            0.942241
#
#                 Количество покупок.1  \
# Выручка, RUB.1              0.942241
#
#                 Количество покупок на платящего пользователя  Выручка, RUB  \
# Выручка, RUB.1                                      0.423344           1.0
#
#                 Средняя выручка на пользователя, RUB  \
# Выручка, RUB.1                              0.966441
#
#                 Средняя выручка на платящего пользователя, RUB  Вернувшиеся  \
# Выручка, RUB.1                                        0.801188     0.806211
#
# ...

# %%
df_corr = df.corr().loc[['Выручка, RUB.1']].T
df_corr[df_corr['Выручка, RUB.1'] > 0.7]
# Out:
#                                                 Выручка, RUB.1
# Пользователи                                          0.838978
# Новые пользователи                                    0.843391
# Количество платящих пользователей                     0.935762
# Количество платящих пользователей.1                   0.935762
# Количество покупок                                    0.942241
# Количество покупок.1                                  0.942241
# Выручка, RUB                                          1.000000
# Средняя выручка на пользователя, RUB                  0.966441
# Средняя выручка на платящего пользователя, RUB        0.801188
# Вернувшиеся                                           0.806211
# Выручка, RUB.1                                        1.000000
