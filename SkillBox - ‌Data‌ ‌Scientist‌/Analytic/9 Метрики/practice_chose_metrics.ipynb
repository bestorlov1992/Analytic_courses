# %% [markdown]
# Для сайта, продающего билеты в кино, составлен список метрик. Определите наиболее
# значимые из них.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Dataset-2.xlsx'
                   , sheet_name='Лист2'
                   , usecols=range(9)
                   , names=['date', 'revenue', 'yield_percent', 'mau', 'new', 'ressurected', 'cnt_items', 'errors', 'avg_check'])
df.head()
# Out:
#       date   revenue  yield_percent        mau      new  ressurected  \
# 0  02.сент  600000.0             91  6209971.0  1271736    4938235.0
# 1  03.сент  539800.0             98  6138791.0  1447192    4691599.0
# 2  05.сент  809765.0             92  6392179.0  1195080    5197099.0
# 3  06.сент  978651.0            100  7697321.0  1387697    6309624.0
# 4  07.сент  769542.0             97  6698070.0  1752918    4945152.0
#
#      cnt_items  errors   avg_check
# 0  1218.323587    3715  492.480000
# 1  1747.030049    3200  308.981520
# 2  2017.756255    2915  401.319534
# 3  2240.143369    1550  436.869806
# 4  1578.282828    1501  487.581811

# %%
df.corr().iloc[:1, 1:]
# Out:
#          yield_percent       mau       new  ressurected  cnt_items   errors  \
# revenue       0.703224  0.884078 -0.069135     0.854884   0.342768 -0.34811
#
#          avg_check
# revenue   0.656413

# %%
df.corr().style.background_gradient(cmap='RdYlGn')
# Out:
# <style type="text/css">
# #T_4e972_row0_col0, #T_4e972_row1_col1, #T_4e972_row2_col2, #T_4e972_row3_col3, #T_4e972_row4_col4, #T_4e972_row5_col5, #T_4e972_row6_col6, #T_4e972_row7_col7 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_4e972_row0_col1 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_4e972_row0_col2 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_4e972_row0_col3 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_4e972_row0_col4, #T_4e972_row4_col0 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_4e972_row0_col5 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_4e972_row0_col6 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T_4e972_row0_col7 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_4e972_row1_col0 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_4e972_row1_col2 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_4e972_row1_col3 {
# ...
