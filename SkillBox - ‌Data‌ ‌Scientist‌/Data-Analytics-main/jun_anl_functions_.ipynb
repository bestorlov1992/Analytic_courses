# %% [markdown]
# # Функции
# ### Домашнее задание

# %% [markdown]
# #### 1.
# Почему возникла ошибка? Объясните и исправьте.

# %%
def factorial(n):
    f = 1
    for i in range(2, n + 1):
        f = f * i
    return f


print(factorial(3))
# Out:
# 6

# %% [markdown]
# **Объяснение:**
# <br><br>
# Ошибка - имя переменной f - не определена глобально. Переменная инициализируется локально в функции factorial
# Исправление: запихнуть вызов функции прямо в print

# %% [markdown]
# #### 2.
# Почему переменная S после запуска функции сохранила значение ноль?

# %%
S = 0
def sum(n, m):
    S = n + m
    return S

print(sum(3, 4))
print(S)
# Out:
# 7
# 0

# %% [markdown]
# **Объяснение:**
# <br><br>
# Функция не изменила значение, тк мы не вызвали функцию sum()

# %% [markdown]
# #### 3.
# Почему возникла ошибка? Объясните и исправьте, чтобы функция могла работать с данными на входе в примере с `res`.

# %%
def mult(*, q, w, e, r, t, y):
    return q + w + e + r + t + y
res = mult(q=1, w=2, e=3, r=4, t=5, y=6)

# %% [markdown]
# **Объяснение:**
# <br><br>
# Ошибка возникла тк мы явно указали в функции mult, что все параметры должны быть именноваными. Мы можем убрать * либо при вызове функции указать имя параметра и присвоить значение.

# %% [markdown]
# #### 4.
# Почему возникла ошибка? Объясните и исправьте, чтобы функция могла работать с данными на входе в примере.

# %%
def power(a, s, *, d):
    res = a ** s ** d
    print(res)
    
power(4, 5, d = 6) 
# ошибка возникла т.к мы указали * после 2го параметра.
# Out:
# ...

# %% [markdown]
# #### 5.
# Почему возникла ошибка? Объясните и исправьте, чтобы функция могла работать с данными на входе в примере.

# %%
def mult2(*args):
    res = 1
    for i in args:
        res += i
    return res

List = [1, 2, 3, 4, 5, 6, 7]
print(mult2(*List))
# мы должны достать каждый элемент списка и передать в функцию
# Out:
# 29

# %% [markdown]
# #### 6.
# Почему возникла ошибка? Объясните и исправьте.

# %%
def some_function(a, b,*args, **kwargs, ):
    pass

# %% [markdown]
# **Объяснение:**
# <br><br>
# Конструкцию **kwargs нельзя располагать до *args. Если это сделать — будет выдано сообщение об ошибке.

# %% [markdown]
# #### 7.
# Почему не был создан новый список при повторном запуске функции? Объясните и исправьте.

# %%
def to_buy(*new_items, shopping_list = []):
    shopping_list = []
    for i in new_items:
        shopping_list.append(i)
    return shopping_list

monday = to_buy('яблоки', 'молоко', 'хлеб')
print(monday)

tuesday = to_buy('груши', 'йогурт', 'мясо')
print(tuesday)
# Out:
# ['яблоки', 'молоко', 'хлеб']
# ['груши', 'йогурт', 'мясо']

# %% [markdown]
# **Объяснение:**
# <br><br>
# Из за того что мы обращаемся к тому же списку в памяти мы не перезаписываем, а добавляем элементы. Нужно иниацилизировать пустой список

# %% [markdown]
# #### 8.
# Измените данную функцию так, чтобы она распечатывала названия продуктов из словаря в примере.

# %%
def print_all(**kwargs):
    for i,name in kwargs.items():
        print(name)


print_all(**{'1' : 'яблоки', '2' :'молоко', '3' : 'хлеб', '4' : 'груши', '5' : 'йогурт', '6' : 'мясо'})
# Out:
# яблоки
# молоко
# хлеб
# груши
# йогурт
# мясо

# %% [markdown]
# #### 9.
# Программисты договорились, что переменные такого рода являются.. *(вопрос из лекции)*

# %%
TOKEN = ...

# %% [markdown]
# **Ответ:**
# <br>
# <br>
# константами

# %% [markdown]
# #### 10.
# Напишите функцию, которая с помощью рекурсии считает сумму последовательности с шагом m. В качестве аргументов подаются целые положительные числа n (последний элемент последовательности) и m (шаг последовательности). Считается, что все члены последовательности являются целыми положительными числами.
#
# Пример:
#
# ```
# sum_of_seq(5, 1)
# 15
#
# sum_of_seq(5, 9)
# 5
#
# sum_of_seq(8, 2)
# 20
# ```

# %%
def sum_of_seq(n,m):
    if n>=1:
        return n+sum_of_seq(n-m,m)
    else:
        return 0
sum_of_seq(8, 2)
# Out:
# 20

# %% [markdown]
# #### 11.
# Напишите функцию, которая возводит число в положительную степень с помощью рекурсии. В качестве аргументов подаются целые положительные числа n (число) и m (степень).

# %%
def prod(n,m):
    if m == 0:
        return 1
    return n * prod(n,m-1)
prod(2,4)
# Out:
# 16

# %% [markdown]
# #### 12.
# Напишите функцию, которая возводит число в отрицательную степень число с помощью рекурсии. В качестве аргументов подаются целое положительное число n (число) и целое отрицательное число m (степень).

# %%
def power(a, n):
    if a == 0:
        return 0
    elif n == 0:
        return 1
    elif n == 1:
        return a
    elif n < 0:
        return 1 / (a * power(a, -n-1))
    else:
        return a * power(a, n-1)
 
a = float(input())
n = int(input())
print(power(a, n))
# Out:
# 2
# -2
# 0.25

# %% [markdown]
# #### 13.
#
# Напишите функцию, которая находит число Фиббоначи по его номеру. В качестве аргумента подается целое положительное число n (число).

# %%
fib1 = 1
fib2 = 1

n = int(input())

i = 0
while i < n - 2:
    fib_sum = fib1 + fib2
    fib1 = fib2
    fib2 = fib_sum
    i = i + 1

print(fib2)
# Out:
# 3
# 2
